# %% [markdown]
# # Variable in Python

# %%
x = 22

print(x)
# Out:
# 22

# %%
type(x)
# Out:
# int

# %%
y = 'mint chocolate chip'
print (y)
# Out:
# mint chocolate chip

# %%
type(y)
# Out:
# str

# %%
x,y,z = 'Chocolate', 'Strawberry', 'Vanilla'

print(x)
print(y)
print(z)
# Out:
# Chocolate
# Strawberry
# Vanilla

# %%
x = y = z = ' Root BeerFloat'

print(x)
print(y)
print(z)
# Out:
#  Root BeerFloat
#  Root BeerFloat
#  Root BeerFloat

# %%
Ice_Cream = 'Chocolate', 'Strawberry', 'Vanilla'
x, y, z = Ice_Cream

print(x)
print(y)
print(z)
# Out:
# Chocolate
# Strawberry
# Vanilla

# %%
#Camel Case

# Test Vareable Case

testVariableCase = ' Vanilla Swirl'

# %%
#Pascal Case

# Test Vareable Case

TestVariableCase = ' Vanilla Swirl'

# %%
#Snake Case

# Test Vareable Case

test_variable_case = ' Vanilla Swirl'

# %%
x = 'Ice Cream is my favorite' + '.'
print(x)
# Out:
# Ice Cream is my favorite.

# %%
y = 3 + 2
print(y)
# Out:
# 5

# %%
x = 'Ice Cream'
y = 'is'
z = 'My Favorite'

print(x,y,z)
# Out:
# Ice Cream is My Favorite

# %%
x = 1
y = 2
z = 3

print(x+y+z)
# Out:
# 6
